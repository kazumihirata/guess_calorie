# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

key = "------------------------"
secret = "------------------------"
wait_time = 1

def main():
    go_download('マグロ寿司', 'sushi')
    go_download('サラダ', 'salad')
    go_download('麻婆豆腐', 'tofu')
    
def go_download(keyword, dir):
    savedir = "./image/" + dir
    if not os.path.exists(savedir):
        os.mkdir(savedir)
    flickr = FlickrAPI(key, secret, format='parsed-json')
    res = flickr.photos.search(
        text = keyword
        , per_page = 300
        , media = 'photos'
        , sort = "relevance"
        , safe_search = 1
        , extras = 'url_q, license'
    )
    
    photos = res['photos']
#     pprint(photos)
#     print(len(photos))

    try:
        for i, photo in enumerate(photos['photo']):
            print(photo)
            url_q = photo['url_q']
            print(url_q)
            filepath = savedir + '/' + photo['id'] + '.jpg'
            print(filepath)
            if os.path.exists(filepath): continue
            
            print(str(i + 1) + ":download=", url_q)
            urlretrieve(url_q, filepath)
            time.sleep(wait_time)
    except:
        import traceback
        traceback.print_exc()
if __name__ == '__main__':
    main()
# Out:
# {'id': '4662491966', 'owner': '15958452@N00', 'secret': 'da30d7e212', 'server': '4040', 'farm': 5, 'title': 'マグロ寿司', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '2', 'url_q': 'https://farm5.staticflickr.com/4040/4662491966_da30d7e212_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4040/4662491966_da30d7e212_q.jpg
# ./image/sushi/4662491966.jpg
# hogehoge
# 1:download= https://farm5.staticflickr.com/4040/4662491966_da30d7e212_q.jpg
# {'id': '36343242451', 'owner': '140295172@N05', 'secret': '3518ff811f', 'server': '4413', 'farm': 5, 'title': 'マグロ握り寿司ダヨー', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4413/36343242451_3518ff811f_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4413/36343242451_3518ff811f_q.jpg
# ./image/sushi/36343242451.jpg
# hogehoge
# 2:download= https://farm5.staticflickr.com/4413/36343242451_3518ff811f_q.jpg
# {'id': '14652227925', 'owner': '55658968@N00', 'secret': '1497ede928', 'server': '3896', 'farm': 4, 'title': 'Sushi!!! / 鮨', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '2', 'url_q': 'https://farm4.staticflickr.com/3896/14652227925_1497ede928_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3896/14652227925_1497ede928_q.jpg
# ./image/sushi/14652227925.jpg
# hogehoge
# 3:download= https://farm4.staticflickr.com/3896/14652227925_1497ede928_q.jpg
# {'id': '8253500451', 'owner': '37102254@N00', 'secret': '21cec1b8c1', 'server': '8497', 'farm': 9, 'title': 'Tuna lean meat マグロ赤身', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm9.staticflickr.com/8497/8253500451_21cec1b8c1_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8497/8253500451_21cec1b8c1_q.jpg
# ./image/sushi/8253500451.jpg
# hogehoge
# 4:download= https://farm9.staticflickr.com/8497/8253500451_21cec1b8c1_q.jpg
# {'id': '5627445160', 'owner': '56960982@N04', 'secret': 'ba81c7667e', 'server': '5145', 'farm': 6, 'title': 'Sushi  ( Tuna / 鮪 / Maguro )', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm6.staticflickr.com/5145/5627445160_ba81c7667e_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/5145/5627445160_ba81c7667e_q.jpg
# ./image/sushi/5627445160.jpg
# hogehoge
# 5:download= https://farm6.staticflickr.com/5145/5627445160_ba81c7667e_q.jpg
# {'id': '5948165395', 'owner': '8344375@N07', 'secret': '8581330973', 'server': '6134', 'farm': 7, 'title': 'Chirashi-Zushi 2', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm7.staticflickr.com/6134/5948165395_8581330973_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm7.staticflickr.com/6134/5948165395_8581330973_q.jpg
# ./image/sushi/5948165395.jpg
# hogehoge
# 6:download= https://farm7.staticflickr.com/6134/5948165395_8581330973_q.jpg
# {'id': '6853723670', 'owner': '22867977@N03', 'secret': '6e4f057e8d', 'server': '7200', 'farm': 8, 'title': 'きときと寿司・マグロ三種', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7200/6853723670_6e4f057e8d_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7200/6853723670_6e4f057e8d_q.jpg
# ./image/sushi/6853723670.jpg
# hogehoge
# 7:download= https://farm8.staticflickr.com/7200/6853723670_6e4f057e8d_q.jpg
# {'id': '4962567450', 'owner': '26989796@N03', 'secret': 'd8ae0e274e', 'server': '4107', 'farm': 5, 'title': 'Colorful Sushi ~ [紅葉]', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '1', 'url_q': 'https://farm5.staticflickr.com/4107/4962567450_d8ae0e274e_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4107/4962567450_d8ae0e274e_q.jpg
# ./image/sushi/4962567450.jpg
# hogehoge
# 8:download= https://farm5.staticflickr.com/4107/4962567450_d8ae0e274e_q.jpg
# {'id': '7189611253', 'owner': '37102254@N00', 'secret': '1cc0c8fe24', 'server': '7097', 'farm': 8, 'title': 'Sushi...', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm8.staticflickr.com/7097/7189611253_1cc0c8fe24_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7097/7189611253_1cc0c8fe24_q.jpg
# ./image/sushi/7189611253.jpg
# hogehoge
# 9:download= https://farm8.staticflickr.com/7097/7189611253_1cc0c8fe24_q.jpg
# {'id': '3126172325', 'owner': '69078600@N00', 'secret': '0c78688beb', 'server': '3197', 'farm': 4, 'title': 'マグロ&中トロ&サーモン', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3197/3126172325_0c78688beb_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3197/3126172325_0c78688beb_q.jpg
# ./image/sushi/3126172325.jpg
# hogehoge
# 10:download= https://farm4.staticflickr.com/3197/3126172325_0c78688beb_q.jpg
# {'id': '6812678475', 'owner': '37102254@N00', 'secret': '8bdb2c78f2', 'server': '7144', 'farm': 8, 'title': 'Sushi set 寿司セット', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm8.staticflickr.com/7144/6812678475_8bdb2c78f2_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7144/6812678475_8bdb2c78f2_q.jpg
# ./image/sushi/6812678475.jpg
# hogehoge
# 11:download= https://farm8.staticflickr.com/7144/6812678475_8bdb2c78f2_q.jpg
# {'id': '9554943132', 'owner': '39227021@N03', 'secret': 'c776757339', 'server': '3693', 'farm': 4, 'title': 'Sushi', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3693/9554943132_c776757339_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3693/9554943132_c776757339_q.jpg
# ./image/sushi/9554943132.jpg
# hogehoge
# 12:download= https://farm4.staticflickr.com/3693/9554943132_c776757339_q.jpg
# {'id': '7905471694', 'owner': '68183480@N05', 'secret': 'cb5e97016f', 'server': '8314', 'farm': 9, 'title': '大量のマグロ寿司', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8314/7905471694_cb5e97016f_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8314/7905471694_cb5e97016f_q.jpg
# ./image/sushi/7905471694.jpg
# hogehoge
# 13:download= https://farm9.staticflickr.com/8314/7905471694_cb5e97016f_q.jpg
# {'id': '15836330493', 'owner': '31708057@N05', 'secret': '400b8ea60a', 'server': '8610', 'farm': 9, 'title': '巻き寿司：サーモンとマグロ', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8610/15836330493_400b8ea60a_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8610/15836330493_400b8ea60a_q.jpg
# ./image/sushi/15836330493.jpg
# hogehoge
# 14:download= https://farm9.staticflickr.com/8610/15836330493_400b8ea60a_q.jpg
# {'id': '6812677483', 'owner': '37102254@N00', 'secret': 'a2ddb2fabd', 'server': '7169', 'farm': 8, 'title': 'Sushi set 寿司セット', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm8.staticflickr.com/7169/6812677483_a2ddb2fabd_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7169/6812677483_a2ddb2fabd_q.jpg
# ./image/sushi/6812677483.jpg
# hogehoge
# 15:download= https://farm8.staticflickr.com/7169/6812677483_a2ddb2fabd_q.jpg
# {'id': '6812679743', 'owner': '37102254@N00', 'secret': '2ec1d175cd', 'server': '7002', 'farm': 8, 'title': 'Sushi set 寿司セット', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm8.staticflickr.com/7002/6812679743_2ec1d175cd_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7002/6812679743_2ec1d175cd_q.jpg
# ./image/sushi/6812679743.jpg
# hogehoge
# 16:download= https://farm8.staticflickr.com/7002/6812679743_2ec1d175cd_q.jpg
# {'id': '5948125975', 'owner': '8344375@N07', 'secret': 'e44c3d0f97', 'server': '6002', 'farm': 7, 'title': 'Futomaki-Zushi', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm7.staticflickr.com/6002/5948125975_e44c3d0f97_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm7.staticflickr.com/6002/5948125975_e44c3d0f97_q.jpg
# ./image/sushi/5948125975.jpg
# hogehoge
# 17:download= https://farm7.staticflickr.com/6002/5948125975_e44c3d0f97_q.jpg
# {'id': '4011290788', 'owner': '15958452@N00', 'secret': 'f1736d58e6', 'server': '3525', 'farm': 4, 'title': 'マグロづくし', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '2', 'url_q': 'https://farm4.staticflickr.com/3525/4011290788_f1736d58e6_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3525/4011290788_f1736d58e6_q.jpg
# ./image/sushi/4011290788.jpg
# hogehoge
# 18:download= https://farm4.staticflickr.com/3525/4011290788_f1736d58e6_q.jpg
# {'id': '8038776413', 'owner': '24233013@N00', 'secret': 'e3832e5ffb', 'server': '8033', 'farm': 9, 'title': 'にぎり寿司', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8033/8038776413_e3832e5ffb_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8033/8038776413_e3832e5ffb_q.jpg
# ./image/sushi/8038776413.jpg
# hogehoge
# 19:download= https://farm9.staticflickr.com/8033/8038776413_e3832e5ffb_q.jpg
# {'id': '5749055849', 'owner': '70323761@N00', 'secret': '883e54614c', 'server': '2118', 'farm': 3, 'title': 'Tokyo - Tsukiji: Sushi Dai - Magurozuke', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm3.staticflickr.com/2118/5749055849_883e54614c_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2118/5749055849_883e54614c_q.jpg
# ./image/sushi/5749055849.jpg
# hogehoge
# 20:download= https://farm3.staticflickr.com/2118/5749055849_883e54614c_q.jpg
# {'id': '10310085173', 'owner': '91049143@N00', 'secret': '7d0cc7b898', 'server': '2872', 'farm': 3, 'title': 'マグロはらみ, 寿司めいじん, 中洲店, 福岡, Fukuoka, 博多, Hakata', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2872/10310085173_7d0cc7b898_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2872/10310085173_7d0cc7b898_q.jpg
# ./image/sushi/10310085173.jpg
# hogehoge
# 21:download= https://farm3.staticflickr.com/2872/10310085173_7d0cc7b898_q.jpg
# {'id': '12437783104', 'owner': '50684673@N00', 'secret': '06ae3ae0bf', 'server': '5527', 'farm': 6, 'title': 'マグロづけ', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm6.staticflickr.com/5527/12437783104_06ae3ae0bf_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/5527/12437783104_06ae3ae0bf_q.jpg
# ./image/sushi/12437783104.jpg
# hogehoge
# 22:download= https://farm6.staticflickr.com/5527/12437783104_06ae3ae0bf_q.jpg
# {'id': '6576306125', 'owner': '27277625@N08', 'secret': '757c1f5230', 'server': '7161', 'farm': 8, 'title': 'マグロの寿司 (Maguro no sushi)', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7161/6576306125_757c1f5230_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7161/6576306125_757c1f5230_q.jpg
# ./image/sushi/6576306125.jpg
# hogehoge
# 23:download= https://farm8.staticflickr.com/7161/6576306125_757c1f5230_q.jpg
# {'id': '11286429683', 'owner': '88523854@N00', 'secret': '3092603dfb', 'server': '2812', 'farm': 3, 'title': 'maguro マグロ', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2812/11286429683_3092603dfb_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2812/11286429683_3092603dfb_q.jpg
# ./image/sushi/11286429683.jpg
# hogehoge
# 24:download= https://farm3.staticflickr.com/2812/11286429683_3092603dfb_q.jpg
# {'id': '3026782785', 'owner': '91003977@N00', 'secret': '35af57ed8d', 'server': '3142', 'farm': 4, 'title': 'いろは寿司＠中目黒', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3142/3026782785_35af57ed8d_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3142/3026782785_35af57ed8d_q.jpg
# ./image/sushi/3026782785.jpg
# hogehoge
# 25:download= https://farm4.staticflickr.com/3142/3026782785_35af57ed8d_q.jpg
# {'id': '8299929176', 'owner': '68601487@N00', 'secret': 'e33bc91bf6', 'server': '8223', 'farm': 9, 'title': '2012年11月 東京_580', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm9.staticflickr.com/8223/8299929176_e33bc91bf6_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8223/8299929176_e33bc91bf6_q.jpg
# ./image/sushi/8299929176.jpg
# hogehoge
# 26:download= https://farm9.staticflickr.com/8223/8299929176_e33bc91bf6_q.jpg
# {'id': '39821506504', 'owner': '90458625@N00', 'secret': 'e87324af43', 'server': '4744', 'farm': 5, 'title': '壽司套餐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4744/39821506504_e87324af43_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4744/39821506504_e87324af43_q.jpg
# ./image/sushi/39821506504.jpg
# hogehoge
# 27:download= https://farm5.staticflickr.com/4744/39821506504_e87324af43_q.jpg
# {'id': '5102101662', 'owner': '26989796@N03', 'secret': '3f8f489916', 'server': '1197', 'farm': 2, 'title': 'Maguro - Tuna - マグロ', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '1', 'url_q': 'https://farm2.staticflickr.com/1197/5102101662_3f8f489916_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm2.staticflickr.com/1197/5102101662_3f8f489916_q.jpg
# ./image/sushi/5102101662.jpg
# hogehoge
# 28:download= https://farm2.staticflickr.com/1197/5102101662_3f8f489916_q.jpg
# {'id': '4716291553', 'owner': '78336695@N00', 'secret': 'dca5bc8eba', 'server': '4057', 'farm': 5, 'title': '今日は寿司 マグロ赤身', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4057/4716291553_dca5bc8eba_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4057/4716291553_dca5bc8eba_q.jpg
# ./image/sushi/4716291553.jpg
# hogehoge
# 29:download= https://farm5.staticflickr.com/4057/4716291553_dca5bc8eba_q.jpg
# {'id': '226987010', 'owner': '46879569@N00', 'secret': '5edf2ef923', 'server': '61', 'farm': 1, 'title': 'レゴのお寿司', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm1.staticflickr.com/61/226987010_5edf2ef923_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm1.staticflickr.com/61/226987010_5edf2ef923_q.jpg
# ./image/sushi/226987010.jpg
# hogehoge
# 30:download= https://farm1.staticflickr.com/61/226987010_5edf2ef923_q.jpg
# {'id': '2148345756', 'owner': '69623388@N00', 'secret': '486d5a089c', 'server': '2173', 'farm': 3, 'title': 'flounder and tuna sushi', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2173/2148345756_486d5a089c_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2173/2148345756_486d5a089c_q.jpg
# ./image/sushi/2148345756.jpg
# hogehoge
# 31:download= https://farm3.staticflickr.com/2173/2148345756_486d5a089c_q.jpg
# {'id': '3391403705', 'owner': '91003977@N00', 'secret': '1ddb1de120', 'server': '3570', 'farm': 4, 'title': 'いろは寿司＠中目黒', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3570/3391403705_1ddb1de120_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3570/3391403705_1ddb1de120_q.jpg
# ./image/sushi/3391403705.jpg
# hogehoge
# 32:download= https://farm4.staticflickr.com/3570/3391403705_1ddb1de120_q.jpg
# {'id': '3680463474', 'owner': '51525230@N00', 'secret': '921d08243e', 'server': '2432', 'farm': 3, 'title': 'うるま市前原幸崎「やざえもん 沖縄具志川店」の「まぐろ赤身」', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2432/3680463474_921d08243e_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2432/3680463474_921d08243e_q.jpg
# ./image/sushi/3680463474.jpg
# hogehoge
# 33:download= https://farm3.staticflickr.com/2432/3680463474_921d08243e_q.jpg
# {'id': '322123461', 'owner': '51525230@N00', 'secret': '9721b5ba2e', 'server': '134', 'farm': 1, 'title': '大阪・ミナミ 相合橋筋「淳ちゃん寿し」の「刺身盛り合わせ」', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm1.staticflickr.com/134/322123461_9721b5ba2e_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm1.staticflickr.com/134/322123461_9721b5ba2e_q.jpg
# ./image/sushi/322123461.jpg
# hogehoge
# 34:download= https://farm1.staticflickr.com/134/322123461_9721b5ba2e_q.jpg
# {'id': '4390097735', 'owner': '10559879@N00', 'secret': '52c7fab74b', 'server': '4033', 'farm': 5, 'title': 'Fresh Tuna Sushi - Satsuki - AUD3', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '5', 'url_q': 'https://farm5.staticflickr.com/4033/4390097735_52c7fab74b_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4033/4390097735_52c7fab74b_q.jpg
# ./image/sushi/4390097735.jpg
# hogehoge
# 35:download= https://farm5.staticflickr.com/4033/4390097735_52c7fab74b_q.jpg
# {'id': '7178378855', 'owner': '68601487@N00', 'secret': '462e68c32f', 'server': '7225', 'farm': 8, 'title': '2012年4月 東京_270', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm8.staticflickr.com/7225/7178378855_462e68c32f_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7225/7178378855_462e68c32f_q.jpg
# ./image/sushi/7178378855.jpg
# hogehoge
# 36:download= https://farm8.staticflickr.com/7225/7178378855_462e68c32f_q.jpg
# {'id': '26745006691', 'owner': '130650195@N02', 'secret': 'd1bda5ab92', 'server': '7605', 'farm': 8, 'title': '海鮮寿司バル マグロドウ', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '6', 'url_q': 'https://farm8.staticflickr.com/7605/26745006691_d1bda5ab92_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7605/26745006691_d1bda5ab92_q.jpg
# ./image/sushi/26745006691.jpg
# hogehoge
# 37:download= https://farm8.staticflickr.com/7605/26745006691_d1bda5ab92_q.jpg
# {'id': '3942851418', 'owner': '65303054@N00', 'secret': '13c67bbf15', 'server': '3271', 'farm': 4, 'title': 'tokujou', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3271/3942851418_13c67bbf15_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3271/3942851418_13c67bbf15_q.jpg
# ./image/sushi/3942851418.jpg
# hogehoge
# 38:download= https://farm4.staticflickr.com/3271/3942851418_13c67bbf15_q.jpg
# {'id': '6853406210', 'owner': '76281374@N02', 'secret': '7e9545d9c0', 'server': '7215', 'farm': 8, 'title': 'Assorted Sushi for 4 Replica 握り桶(四人前) 食品サンプル', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7215/6853406210_7e9545d9c0_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7215/6853406210_7e9545d9c0_q.jpg
# ./image/sushi/6853406210.jpg
# hogehoge
# 39:download= https://farm8.staticflickr.com/7215/6853406210_7e9545d9c0_q.jpg
# {'id': '30839592685', 'owner': '77812424@N03', 'secret': 'b327b9b3c7', 'server': '5799', 'farm': 6, 'title': 'マグロ握り寿司', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '2', 'url_q': 'https://farm6.staticflickr.com/5799/30839592685_b327b9b3c7_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/
 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '4', 'url_q': 'https://farm9.staticflickr.com/8352/8400787365_bf65997aee_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8352/8400787365_bf65997aee_q.jpg
# ./image/sushi/8400787365.jpg
# hogehoge
# 72:download= https://farm9.staticflickr.com/8352/8400787365_bf65997aee_q.jpg
# {'id': '2678128917', 'owner': '12832970@N00', 'secret': '166a51c5e4', 'server': '3283', 'farm': 4, 'title': 'Sushi - Tuna Spectrum', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '4', 'url_q': 'https://farm4.staticflickr.com/3283/2678128917_166a51c5e4_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3283/2678128917_166a51c5e4_q.jpg
# ./image/sushi/2678128917.jpg
# hogehoge
# 73:download= https://farm4.staticflickr.com/3283/2678128917_166a51c5e4_q.jpg
# {'id': '3703477577', 'owner': '34619662@N00', 'secret': '04e2077217', 'server': '3525', 'farm': 4, 'title': 'まぐろ五種盛', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '1', 'url_q': 'https://farm4.staticflickr.com/3525/3703477577_04e2077217_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3525/3703477577_04e2077217_q.jpg
# ./image/sushi/3703477577.jpg
# hogehoge
# 74:download= https://farm4.staticflickr.com/3525/3703477577_04e2077217_q.jpg
# {'id': '5993959384', 'owner': '45026991@N03', 'secret': 'd9d5197ea4', 'server': '6146', 'farm': 7, 'title': '久しぶりの寿司は美味かったー。やっぱマグロやな。', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm7.staticflickr.com/6146/5993959384_d9d5197ea4_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm7.staticflickr.com/6146/5993959384_d9d5197ea4_q.jpg
# ./image/sushi/5993959384.jpg
# hogehoge
# 75:download= https://farm7.staticflickr.com/6146/5993959384_d9d5197ea4_q.jpg
# {'id': '7363613812', 'owner': '68601487@N00', 'secret': '0ef7ec6069', 'server': '7236', 'farm': 8, 'title': '2012年4月 東京_272', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm8.staticflickr.com/7236/7363613812_0ef7ec6069_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7236/7363613812_0ef7ec6069_q.jpg
# ./image/sushi/7363613812.jpg
# hogehoge
# 76:download= https://farm8.staticflickr.com/7236/7363613812_0ef7ec6069_q.jpg
# {'id': '3592200386', 'owner': '30972601@N06', 'secret': '32d4574c0b', 'server': '2454', 'farm': 3, 'title': '朝ご飯だそうです', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2454/3592200386_32d4574c0b_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2454/3592200386_32d4574c0b_q.jpg
# ./image/sushi/3592200386.jpg
# hogehoge
# 77:download= https://farm3.staticflickr.com/2454/3592200386_32d4574c0b_q.jpg
# {'id': '7508080072', 'owner': '54011217@N06', 'secret': '70de5ea7fc', 'server': '8289', 'farm': 9, 'title': '金沢老舗のお寿司屋さん', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8289/7508080072_70de5ea7fc_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8289/7508080072_70de5ea7fc_q.jpg
# ./image/sushi/7508080072.jpg
# hogehoge
# 78:download= https://farm9.staticflickr.com/8289/7508080072_70de5ea7fc_q.jpg
# {'id': '16953651115', 'owner': '52607360@N04', 'secret': 'e133cf7cbe', 'server': '7584', 'farm': 8, 'title': '初めてちゃんとした寿司！マグロと鮭！', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7584/16953651115_e133cf7cbe_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7584/16953651115_e133cf7cbe_q.jpg
# ./image/sushi/16953651115.jpg
# hogehoge
# 79:download= https://farm8.staticflickr.com/7584/16953651115_e133cf7cbe_q.jpg
# {'id': '4774431754', 'owner': '10188381@N08', 'secret': '59b72e8e90', 'server': '4077', 'farm': 5, 'title': 'Bonito sushi from Magurobito @ Okachimachi sashimi rice ( near Ueno )', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4077/4774431754_59b72e8e90_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4077/4774431754_59b72e8e90_q.jpg
# ./image/sushi/4774431754.jpg
# hogehoge
# 80:download= https://farm5.staticflickr.com/4077/4774431754_59b72e8e90_q.jpg
# {'id': '33577625964', 'owner': '55641641@N04', 'secret': '03d30e99f2', 'server': '4176', 'farm': 5, 'title': 'Sushi!!! 昨日のランチに寿司を食べ損ねたのでリベンジ！やっぱマグロがなんだかんだで美味しいですねー。', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4176/33577625964_03d30e99f2_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4176/33577625964_03d30e99f2_q.jpg
# ./image/sushi/33577625964.jpg
# hogehoge
# 81:download= https://farm5.staticflickr.com/4176/33577625964_03d30e99f2_q.jpg
# {'id': '15017845212', 'owner': '40935816@N05', 'secret': '17513e25dc', 'server': '5575', 'farm': 6, 'title': 'IMG_0446 マグロ・納豆丼 (crosseye 3D)', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm6.staticflickr.com/5575/15017845212_17513e25dc_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/5575/15017845212_17513e25dc_q.jpg
# ./image/sushi/15017845212.jpg
# hogehoge
# 82:download= https://farm6.staticflickr.com/5575/15017845212_17513e25dc_q.jpg
# {'id': '8300025250', 'owner': '68601487@N00', 'secret': '4455f3c5df', 'server': '8223', 'farm': 9, 'title': '2012年11月 東京_592', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm9.staticflickr.com/8223/8300025250_4455f3c5df_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8223/8300025250_4455f3c5df_q.jpg
# ./image/sushi/8300025250.jpg
# hogehoge
# 83:download= https://farm9.staticflickr.com/8223/8300025250_4455f3c5df_q.jpg
# {'id': '4760851530', 'owner': '89442701@N00', 'secret': '2a986feab3', 'server': '4095', 'farm': 5, 'title': '鮪魚赤身', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4095/4760851530_2a986feab3_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4095/4760851530_2a986feab3_q.jpg
# ./image/sushi/4760851530.jpg
# hogehoge
# 84:download= https://farm5.staticflickr.com/4095/4760851530_2a986feab3_q.jpg
# {'id': '8480194775', 'owner': '21656023@N05', 'secret': '42153a5a0d', 'server': '8102', 'farm': 9, 'title': '寿司（マグロ、サーモン、ハマチ）', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8102/8480194775_42153a5a0d_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8102/8480194775_42153a5a0d_q.jpg
# ./image/sushi/8480194775.jpg
# hogehoge
# 85:download= https://farm9.staticflickr.com/8102/8480194775_42153a5a0d_q.jpg
# {'id': '4823320545', 'owner': '43936386@N02', 'secret': '7030155765', 'server': '4139', 'farm': 5, 'title': 'Tsukiji Market', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4139/4823320545_7030155765_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4139/4823320545_7030155765_q.jpg
# ./image/sushi/4823320545.jpg
# hogehoge
# 86:download= https://farm5.staticflickr.com/4139/4823320545_7030155765_q.jpg
# {'id': '26745005841', 'owner': '130650195@N02', 'secret': 'd159726753', 'server': '7431', 'farm': 8, 'title': '海鮮寿司バル マグロドウ', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '6', 'url_q': 'https://farm8.staticflickr.com/7431/26745005841_d159726753_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7431/26745005841_d159726753_q.jpg
# ./image/sushi/26745005841.jpg
# hogehoge
# 87:download= https://farm8.staticflickr.com/7431/26745005841_d159726753_q.jpg
# {'id': '8190908386', 'owner': '63746676@N08', 'secret': '3a60a21019', 'server': '8068', 'farm': 9, 'title': '11/16 19:28 #マグロ #鮪 #sushi #寿司 #大江戸寿司 #回転寿司 #阿佐ヶ谷 #asagaya #dinner #uzuki', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8068/8190908386_3a60a21019_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8068/8190908386_3a60a21019_q.jpg
# ./image/sushi/8190908386.jpg
# hogehoge
# 88:download= https://farm9.staticflickr.com/8068/8190908386_3a60a21019_q.jpg
# {'id': '2946796169', 'owner': '51525230@N00', 'secret': '4afb48fb2c', 'server': '3247', 'farm': 4, 'title': '俵石閣 トロ握り', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3247/2946796169_4afb48fb2c_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3247/2946796169_4afb48fb2c_q.jpg
# ./image/sushi/2946796169.jpg
# hogehoge
# 89:download= https://farm4.staticflickr.com/3247/2946796169_4afb48fb2c_q.jpg
# {'id': '2468488672', 'owner': '91003977@N00', 'secret': 'fd558e3534', 'server': '2116', 'farm': 3, 'title': 'いろは寿司＠中目黒', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2116/2468488672_fd558e3534_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2116/2468488672_fd558e3534_q.jpg
# ./image/sushi/2468488672.jpg
# hogehoge
# 90:download= https://farm3.staticflickr.com/2116/2468488672_fd558e3534_q.jpg
# {'id': '8354224976', 'owner': '21656023@N05', 'secret': 'b835392278', 'server': '8186', 'farm': 9, 'title': 'サーモンとマグロの寿司', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8186/8354224976_b835392278_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8186/8354224976_b835392278_q.jpg
# ./image/sushi/8354224976.jpg
# hogehoge
# 91:download= https://farm9.staticflickr.com/8186/8354224976_b835392278_q.jpg
# {'id': '1177464373', 'owner': '10608072@N02', 'secret': 'b5d898df24', 'server': '1352', 'farm': 2, 'title': 'Sushi', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm2.staticflickr.com/1352/1177464373_b5d898df24_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm2.staticflickr.com/1352/1177464373_b5d898df24_q.jpg
# ./image/sushi/1177464373.jpg
# hogehoge
# 92:download= https://farm2.staticflickr.com/1352/1177464373_b5d898df24_q.jpg
# {'id': '5353744133', 'owner': '22761075@N02', 'secret': '2b35d70bcd', 'server': '5128', 'farm': 6, 'title': 'センパイと立ち食い寿司でマグロ祭り、一貫50円(・▽・)', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm6.staticflickr.com/5128/5353744133_2b35d70bcd_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/5128/5353744133_2b35d70bcd_q.jpg
# ./image/sushi/5353744133.jpg
# hogehoge
# 93:download= https://farm6.staticflickr.com/5128/5353744133_2b35d70bcd_q.jpg
# {'id': '4365009054', 'owner': '20324540@N00', 'secret': 'eb25eef7a4', 'server': '4061', 'farm': 5, 'title': 'Tuna-don at Sushi Zero One', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '5', 'url_q': 'https://farm5.staticflickr.com/4061/4365009054_eb25eef7a4_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4061/4365009054_eb25eef7a4_q.jpg
# ./image/sushi/4365009054.jpg
# hogehoge
# 94:download= https://farm5.staticflickr.com/4061/4365009054_eb25eef7a4_q.jpg
# {'id': '6650945421', 'owner': '22671277@N04', 'secret': '51c8ba0cec', 'server': '7024', 'farm': 8, 'title': 'R0013960.JPG', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7024/6650945421_51c8ba0cec_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7024/6650945421_51c8ba0cec_q.jpg
# ./image/sushi/6650945421.jpg
# hogehoge
# 95:download= https://farm8.staticflickr.com/7024/6650945421_51c8ba0cec_q.jpg
# {'id': '37609501125', 'owner': '159405655@N04', 'secret': 'd2aa226e72', 'server': '4534', 'farm': 5, 'title': '西友\u3000マグロたたき巻いなり\u3000298', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4534/37609501125_d2aa226e72_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4534/37609501125_d2aa226e72_q.jpg
# ./image/sushi/37609501125.jpg
# hogehoge
# 96:download= https://farm5.staticflickr.com/4534/37609501125_d2aa226e72_q.jpg
# {'id': '2209229340', 'owner': '21381123@N06', 'secret': 'dd76ee6022', 'server': '2181', 'farm': 3, 'title': '伊豆大島', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2181/2209229340_dd76ee6022_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2181/2209229340_dd76ee6022_q.jpg
# ./image/sushi/2209229340.jpg
# hogehoge
# 97:download= https://farm3.staticflickr.com/2181/2209229340_dd76ee6022_q.jpg
# {'id': '16354735692', 'owner': '127961895@N06', 'secret': '0cd9520672', 'server': '8681', 'farm': 9, 'title': '城崎温泉（をり鶴）', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8681/16354735692_0cd9520672_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8681/16354735692_0cd9520672_q.jpg
# ./image/sushi/16354735692.jpg
# hogehoge
# 98:download= https://farm9.staticflickr.com/8681/16354735692_0cd9520672_q.jpg
# ...
# {'id': '5696215512', 'owner': '57794954@N08', 'secret': '9c7d8a8a36', 'server': '3289', 'farm': 4, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3289/5696215512_9c7d8a8a36_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3289/5696215512_9c7d8a8a36_q.jpg
# ./image/tofu/5696215512.jpg
# hogehoge
# 267:download= https://farm4.staticflickr.com/3289/5696215512_9c7d8a8a36_q.jpg
# {'id': '4010845464', 'owner': '43391457@N08', 'secret': '0747fe0868', 'server': '2553', 'farm': 3, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2553/4010845464_0747fe0868_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2553/4010845464_0747fe0868_q.jpg
# ./image/tofu/4010845464.jpg
# hogehoge
# 268:download= https://farm3.staticflickr.com/2553/4010845464_0747fe0868_q.jpg
# {'id': '2492722326', 'owner': '23724118@N07', 'secret': '5014cbd841', 'server': '2016', 'farm': 3, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2016/2492722326_5014cbd841_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2016/2492722326_5014cbd841_q.jpg
# ./image/tofu/2492722326.jpg
# hogehoge
# 269:download= https://farm3.staticflickr.com/2016/2492722326_5014cbd841_q.jpg
# {'id': '3855972972', 'owner': '40580615@N05', 'secret': '17768f1be6', 'server': '2519', 'farm': 3, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2519/3855972972_17768f1be6_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2519/3855972972_17768f1be6_q.jpg
# ./image/tofu/3855972972.jpg
# hogehoge
# 270:download= https://farm3.staticflickr.com/2519/3855972972_17768f1be6_q.jpg
# {'id': '494811625', 'owner': '32134445@N00', 'secret': 'e8fd7e8af6', 'server': '204', 'farm': 1, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm1.staticflickr.com/204/494811625_e8fd7e8af6_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm1.staticflickr.com/204/494811625_e8fd7e8af6_q.jpg
# ./image/tofu/494811625.jpg
# hogehoge
# 271:download= https://farm1.staticflickr.com/204/494811625_e8fd7e8af6_q.jpg
# {'id': '432938184', 'owner': '7201575@N04', 'secret': '24d9be41af', 'server': '179', 'farm': 1, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm1.staticflickr.com/179/432938184_24d9be41af_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm1.staticflickr.com/179/432938184_24d9be41af_q.jpg
# ./image/tofu/432938184.jpg
# hogehoge
# 272:download= https://farm1.staticflickr.com/179/432938184_24d9be41af_q.jpg
# {'id': '14529190331', 'owner': '25811172@N05', 'secret': '92a497d293', 'server': '5523', 'farm': 6, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm6.staticflickr.com/5523/14529190331_92a497d293_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/5523/14529190331_92a497d293_q.jpg
# ./image/tofu/14529190331.jpg
# hogehoge
# 273:download= https://farm6.staticflickr.com/5523/14529190331_92a497d293_q.jpg
# {'id': '12379927334', 'owner': '60137255@N03', 'secret': '4a73f3d786', 'server': '2852', 'farm': 3, 'title': '麻婆豆腐。', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2852/12379927334_4a73f3d786_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2852/12379927334_4a73f3d786_q.jpg
# ./image/tofu/12379927334.jpg
# hogehoge
# 274:download= https://farm3.staticflickr.com/2852/12379927334_4a73f3d786_q.jpg
# {'id': '1950786591', 'owner': '50825834@N00', 'secret': '8d2c994cec', 'server': '2252', 'farm': 3, 'title': '麻婆豆腐～～～', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2252/1950786591_8d2c994cec_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2252/1950786591_8d2c994cec_q.jpg
# ./image/tofu/1950786591.jpg
# hogehoge
# 275:download= https://farm3.staticflickr.com/2252/1950786591_8d2c994cec_q.jpg
# {'id': '4381159814', 'owner': '7704714@N07', 'secret': '44fbaa4ebe', 'server': '4042', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '3', 'url_q': 'https://farm5.staticflickr.com/4042/4381159814_44fbaa4ebe_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4042/4381159814_44fbaa4ebe_q.jpg
# ./image/tofu/4381159814.jpg
# hogehoge
# 276:download= https://farm5.staticflickr.com/4042/4381159814_44fbaa4ebe_q.jpg
# {'id': '2587256734', 'owner': '22075278@N04', 'secret': '2cba4508b4', 'server': '3260', 'farm': 4, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3260/2587256734_2cba4508b4_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3260/2587256734_2cba4508b4_q.jpg
# ./image/tofu/2587256734.jpg
# hogehoge
# 277:download= https://farm4.staticflickr.com/3260/2587256734_2cba4508b4_q.jpg
# {'id': '8660074350', 'owner': '49231033@N07', 'secret': '7f92b10926', 'server': '8122', 'farm': 9, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8122/8660074350_7f92b10926_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8122/8660074350_7f92b10926_q.jpg
# ./image/tofu/8660074350.jpg
# hogehoge
# 278:download= https://farm9.staticflickr.com/8122/8660074350_7f92b10926_q.jpg
# {'id': '3667500847', 'owner': '20437871@N04', 'secret': '3795596cd2', 'server': '2429', 'farm': 3, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2429/3667500847_3795596cd2_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2429/3667500847_3795596cd2_q.jpg
# ./image/tofu/3667500847.jpg
# hogehoge
# 279:download= https://farm3.staticflickr.com/2429/3667500847_3795596cd2_q.jpg
# {'id': '2061618276', 'owner': '12512934@N05', 'secret': 'b3f59a1157', 'server': '2030', 'farm': 3, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm3.staticflickr.com/2030/2061618276_b3f59a1157_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm3.staticflickr.com/2030/2061618276_b3f59a1157_q.jpg
# ./image/tofu/2061618276.jpg
# hogehoge
# 280:download= https://farm3.staticflickr.com/2030/2061618276_b3f59a1157_q.jpg
# {'id': '5175436966', 'owner': '23278513@N05', 'secret': 'cd5dc16212', 'server': '4133', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4133/5175436966_cd5dc16212_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4133/5175436966_cd5dc16212_q.jpg
# ./image/tofu/5175436966.jpg
# hogehoge
# 281:download= https://farm5.staticflickr.com/4133/5175436966_cd5dc16212_q.jpg
# {'id': '4327329545', 'owner': '51704543@N00', 'secret': '2b375aa39d', 'server': '4039', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '2', 'url_q': 'https://farm5.staticflickr.com/4039/4327329545_2b375aa39d_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4039/4327329545_2b375aa39d_q.jpg
# ./image/tofu/4327329545.jpg
# hogehoge
# 282:download= https://farm5.staticflickr.com/4039/4327329545_2b375aa39d_q.jpg
# {'id': '4896619968', 'owner': '63458328@N00', 'secret': '3912e79717', 'server': '4116', 'farm': 5, 'title': '麻婆豆腐！', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4116/4896619968_3912e79717_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4116/4896619968_3912e79717_q.jpg
# ./image/tofu/4896619968.jpg
# hogehoge
# 283:download= https://farm5.staticflickr.com/4116/4896619968_3912e79717_q.jpg
# {'id': '5014460479', 'owner': '33655731@N07', 'secret': '6d947b0cca', 'server': '4089', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '1', 'url_q': 'https://farm5.staticflickr.com/4089/5014460479_6d947b0cca_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4089/5014460479_6d947b0cca_q.jpg
# ./image/tofu/5014460479.jpg
# hogehoge
# 284:download= https://farm5.staticflickr.com/4089/5014460479_6d947b0cca_q.jpg
# {'id': '13446233653', 'owner': '54819012@N08', 'secret': 'c1769df004', 'server': '7451', 'farm': 8, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7451/13446233653_c1769df004_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7451/13446233653_c1769df004_q.jpg
# ./image/tofu/13446233653.jpg
# hogehoge
# 285:download= https://farm8.staticflickr.com/7451/13446233653_c1769df004_q.jpg
# {'id': '5006359749', 'owner': '7950135@N04', 'secret': 'fe83ba4a88', 'server': '4092', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4092/5006359749_fe83ba4a88_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4092/5006359749_fe83ba4a88_q.jpg
# ./image/tofu/5006359749.jpg
# hogehoge
# 286:download= https://farm5.staticflickr.com/4092/5006359749_fe83ba4a88_q.jpg
# {'id': '4900656749', 'owner': '30008972@N07', 'secret': 'ae544cb1b3', 'server': '4074', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4074/4900656749_ae544cb1b3_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4074/4900656749_ae544cb1b3_q.jpg
# ./image/tofu/4900656749.jpg
# hogehoge
# 287:download= https://farm5.staticflickr.com/4074/4900656749_ae544cb1b3_q.jpg
# {'id': '6065451868', 'owner': '63634330@N02', 'secret': '2be53b2fbd', 'server': '6084', 'farm': 7, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm7.staticflickr.com/6084/6065451868_2be53b2fbd_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm7.staticflickr.com/6084/6065451868_2be53b2fbd_q.jpg
# ./image/tofu/6065451868.jpg
# hogehoge
# 288:download= https://farm7.staticflickr.com/6084/6065451868_2be53b2fbd_q.jpg
# {'id': '1171928892', 'owner': '94943998@N00', 'secret': '8d639f7495', 'server': '1220', 'farm': 2, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm2.staticflickr.com/1220/1171928892_8d639f7495_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm2.staticflickr.com/1220/1171928892_8d639f7495_q.jpg
# ./image/tofu/1171928892.jpg
# hogehoge
# 289:download= https://farm2.staticflickr.com/1220/1171928892_8d639f7495_q.jpg
# {'id': '5267767037', 'owner': '20889739@N00', 'secret': '028c8f21b0', 'server': '5169', 'farm': 6, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm6.staticflickr.com/5169/5267767037_028c8f21b0_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm6.staticflickr.com/5169/5267767037_028c8f21b0_q.jpg
# ./image/tofu/5267767037.jpg
# hogehoge
# 290:download= https://farm6.staticflickr.com/5169/5267767037_028c8f21b0_q.jpg
# {'id': '6547497019', 'owner': '58669164@N00', 'secret': 'da1da1163b', 'server': '7020', 'farm': 8, 'title': '麻婆豆腐 ✨☺', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7020/6547497019_da1da1163b_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7020/6547497019_da1da1163b_q.jpg
# ./image/tofu/6547497019.jpg
# hogehoge
# 291:download= https://farm8.staticflickr.com/7020/6547497019_da1da1163b_q.jpg
# {'id': '4262108272', 'owner': '31946071@N06', 'secret': 'e96c48cdc7', 'server': '4071', 'farm': 5, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4071/4262108272_e96c48cdc7_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4071/4262108272_e96c48cdc7_q.jpg
# ./image/tofu/4262108272.jpg
# hogehoge
# 292:download= https://farm5.staticflickr.com/4071/4262108272_e96c48cdc7_q.jpg
# {'id': '7961349142', 'owner': '55437744@N02', 'secret': 'a1a2d7737c', 'server': '8172', 'farm': 9, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8172/7961349142_a1a2d7737c_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8172/7961349142_a1a2d7737c_q.jpg
# ./image/tofu/7961349142.jpg
# hogehoge
# 293:download= https://farm9.staticflickr.com/8172/7961349142_a1a2d7737c_q.jpg
# {'id': '25150472387', 'owner': '101113274@N06', 'secret': '42cbb341e6', 'server': '4625', 'farm': 5, 'title': '純素麻婆豆腐 vegan-ma-po-tofu (4)', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm5.staticflickr.com/4625/25150472387_42cbb341e6_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm5.staticflickr.com/4625/25150472387_42cbb341e6_q.jpg
# ./image/tofu/25150472387.jpg
# hogehoge
# 294:download= https://farm5.staticflickr.com/4625/25150472387_42cbb341e6_q.jpg
# {'id': '2930556311', 'owner': '27668062@N05', 'secret': '6cde521c0c', 'server': '3241', 'farm': 4, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm4.staticflickr.com/3241/2930556311_6cde521c0c_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm4.staticflickr.com/3241/2930556311_6cde521c0c_q.jpg
# ./image/tofu/2930556311.jpg
# hogehoge
# 295:download= https://farm4.staticflickr.com/3241/2930556311_6cde521c0c_q.jpg
# {'id': '6992687004', 'owner': '36187678@N03', 'secret': 'b3f95e9d8b', 'server': '7249', 'farm': 8, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm8.staticflickr.com/7249/6992687004_b3f95e9d8b_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm8.staticflickr.com/7249/6992687004_b3f95e9d8b_q.jpg
# ./image/tofu/6992687004.jpg
# hogehoge
# 296:download= https://farm8.staticflickr.com/7249/6992687004_b3f95e9d8b_q.jpg
# {'id': '8534177252', 'owner': '79755713@N00', 'secret': '20ba3c5f11', 'server': '8528', 'farm': 9, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8528/8534177252_20ba3c5f11_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8528/8534177252_20ba3c5f11_q.jpg
# ./image/tofu/8534177252.jpg
# hogehoge
# 297:download= https://farm9.staticflickr.com/8528/8534177252_20ba3c5f11_q.jpg
# {'id': '6038244260', 'owner': '49168459@N03', 'secret': 'cf26fd81f4', 'server': '6147', 'farm': 7, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm7.staticflickr.com/6147/6038244260_cf26fd81f4_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm7.staticflickr.com/6147/6038244260_cf26fd81f4_q.jpg
# ./image/tofu/6038244260.jpg
# hogehoge
# 298:download= https://farm7.staticflickr.com/6147/6038244260_cf26fd81f4_q.jpg
# {'id': '8014509478', 'owner': '63517846@N02', 'secret': '455a496b51', 'server': '8441', 'farm': 9, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm9.staticflickr.com/8441/8014509478_455a496b51_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm9.staticflickr.com/8441/8014509478_455a496b51_q.jpg
# ./image/tofu/8014509478.jpg
# hogehoge
# 299:download= https://farm9.staticflickr.com/8441/8014509478_455a496b51_q.jpg
# {'id': '34343322', 'owner': '21797746@N00', 'secret': '42d8c72623', 'server': '23', 'farm': 1, 'title': '麻婆豆腐', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0, 'license': '0', 'url_q': 'https://farm1.staticflickr.com/23/34343322_42d8c72623_q.jpg', 'height_q': '150', 'width_q': '150'}
# https://farm1.staticflickr.com/23/34343322_42d8c72623_q.jpg
# ./image/tofu/34343322.jpg
# hogehoge
# 300:download= https://farm1.staticflickr.com/23/34343322_42d8c72623_q.jpg

# %%
import numpy as np
from PIL import Image
import os, glob, random

outfile = "image/photos.npz"
max_photo = 100 # TODO:
photo_size = 32
x = []
y = []

def main():
    glob_files("./image/sushi", 0)
    glob_files("./image/salad", 1)
    glob_files("./image/tofu", 2)
    np.savez(outfile, x=x, y=y)
    print("保存しました:" + outfile, len(x))
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    num = 0
    for f in files:
        if num >= max_photo: break
        num += 1
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((photo_size, photo_size))
        img = np.asarray(img)
        x.append(img)
        y.append(label)

if __name__ == '__main__':
    main()
# Out:
# 保存しました:image/photos.npz 300

# %%
import matplotlib.pyplot as plt

photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

idx = 0

plt.figure(figsize=(10, 10))

for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.title(y[i + idx])
    plt.imshow(x[i + idx])
plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop

# define cnn model
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
                    kernel_size=(3, 3),
                    activation='relu',
                    input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compili(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        METRICS=['accuracy']
    )
    return model

# %%
# import cnn_model
import keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

im_rows = 32
im_cols = 32
im_color = 3
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255

y = keras.utils.np_utils.to_categorical(y.astype('int32'), nb_classes)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size=0.8)

model = get_model(in_shape, nb_classes)

hist = model.fit(x_train, y_train, 
                 batch_size=32,
                epochs=20,
                 verbose=1,
                 validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])

plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title(['Loss'])
plt.legend(['train', 'test'], loc='upper left')
plt.show()

model.save_weights('./image/photos-model-light.hdf5')
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2069: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Train on 240 samples, validate on 60 samples
# Epoch 1/20
# 240/240 [==============================] - 1s 6ms/step - loss: 1.1352 - acc: 0.3208 - val_loss: 1.1030 - val_acc: 0.3833
# Epoch 2/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.1036 - acc: 0.3208 - val_loss: 1.1050 - val_acc: 0.2500
# Epoch 3/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.0991 - acc: 0.3875 - val_loss: 1.0862 - val_acc: 0.4667
# Epoch 4/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.1296 - acc: 0.3583 - val_loss: 1.0940 - val_acc: 0.3667
# Epoch 5/20
# 240/240 [==============================] - 1s 4ms/step - loss: 1.0761 - acc: 0.4458 - val_loss: 1.1123 - val_acc: 0.4500
# Epoch 6/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.0474 - acc: 0.4917 - val_loss: 1.0213 - val_acc: 0.5000
# Epoch 7/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.0970 - acc: 0.4083 - val_loss: 1.0788 - val_acc: 0.3667
# Epoch 8/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.0056 - acc: 0.5167 - val_loss: 0.9312 - val_acc: 0.5500
# Epoch 9/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.9651 - acc: 0.5458 - val_loss: 1.1239 - val_acc: 0.4667
# Epoch 10/20
# 240/240 [==============================] - 1s 3ms/step - loss: 1.0282 - acc: 0.4875 - val_loss: 0.9356 - val_acc: 0.5167
# Epoch 11/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.8816 - acc: 0.6083 - val_loss: 1.1241 - val_acc: 0.4167
# Epoch 12/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.8776 - acc: 0.6000 - val_loss: 1.0655 - val_acc: 0.4333
# Epoch 13/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.9328 - acc: 0.5417 - val_loss: 0.8990 - val_acc: 0.6000
# Epoch 14/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.8342 - acc: 0.6292 - val_loss: 0.8327 - val_acc: 0.6000
# Epoch 15/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.8837 - acc: 0.6167 - val_loss: 0.8578 - val_acc: 0.6167
# Epoch 16/20
# 240/240 [==============================] - 1s 4ms/step - loss: 0.8729 - acc: 0.6125 - val_loss: 0.8417 - val_acc: 0.6333
# Epoch 17/20
# 240/240 [==============================] - 1s 4ms/step - loss: 0.8116 - acc: 0.6375 - val_loss: 0.8822 - val_acc: 0.5833
# Epoch 18/20
# 240/240 [==============================] - 1s 4ms/step - loss: 0.7570 - acc: 0.6500 - val_loss: 0.7660 - val_acc: 0.6500
# Epoch 19/20
# 240/240 [==============================] - 1s 3ms/step - loss: 0.7073 - acc: 0.7458 - val_loss: 1.1705 - val_acc: 0.4500
# Epoch 20/20
# 240/240 [==============================] - 1s 4ms/step - loss: 0.7245 - acc: 0.6917 - val_loss: 0.7950 - val_acc: 0.7000
# 60/60 [==============================] - 0s 1ms/step
# 正解率= 0.699999996026357 loss= 0.7950255036354065

# %%
import keras
from keras.models import  Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import  RMSprop

#cnnのモデルを定義する

def def_model(in_shape,nb_classes):
    model=Sequential()
    model.add(Conv2D(32,
                    kernel_size=(3,3),
                    activation="relu",
                    input_shape=in_shape))
    model.add(Conv2D(32,(3,3),activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3),activation="relu"))
    model.add(Conv2D(64,(3,3),activation="relu",name="relu_conv2"))
   #最後の畳み込み層の名称を後ほど使うので定義しておく。
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes,activation="softmax"))

    return model

#コンパイル済みのcnnのモデルを返す
def get_model(in_shape,nb_classes):
    model=def_model(in_shape,nb_classes)
    model.compile(
        loss="categorical_crossentropy",
        optimizer=RMSprop(),
        metrics=["accuracy"])
    return model

# %%
import matplotlib.pyplot as plt
import cv2

photos = np.load('image/photos.npz')
x = photos['x']
img = x[12]

plt.figure(figsize=(10, 10))

for i in range(36):
    plt.subplot(6, 6, i + 1)
    center = (16, 16)
    angle = i * 5
    scale = 1.0
    mtx = cv2.getRotationMatrix2D(center, angle, scale)
    img2 = cv2.warpAffine(img, mtx, (32, 32))
    
    plt.imshow(img2)
plt.show()

# %%
import keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

target_image = "test-sushi.jpeg"

im_rows = 32
im_cols = 32
im_color  = 3
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

LABELS = ["寿司", "サラダ", "麻婆豆腐"]
CALORIES = [588, 118, 648]

model = get_model(in_shape, nb_classes)
model.load_weights('./image/photos-model-light.hdf5')

def check_photo(path):
    img = Image.open(path)
    img = img.convert("RGB")
    img = img.resize((im_cols, im_rows))
    plt.imshow(img)
    plt.show()
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color)
    x = x / 255
    
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = int(pre[idx] * 100)
    return (idx, per)

def check_photo_str(path):
    idx, per = check_photo(path)
    
    print("This picture is ", LABELS[idx], " and calorie is ", CALORIES[idx], " kcal")
    print("The accuracy is ", per, " %")

if __name__ == '__main__':
    check_photo_str('test_sushi.jpeg')
# Out:
# This picture is  寿司  and calorie is  588  kcal
# The accuracy is  97  %
